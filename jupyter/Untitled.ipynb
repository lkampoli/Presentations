# %%
# %matplotlib notebook

# %%
import tools
import numpy as np
import matplotlib.pyplot as plt

# %%
con=[]
Vcon=[]
### Value constraints
Vcon.append([0.,-1.0])
Vcon.append([1.,0.0])
con.append(Vcon)
### 1.st Derivative/spacing constraint
Dcon=[]
Dcon.append([0,0.3])
con.append(Dcon)
### 2.nd Deriv
Dcon=[]
Dcon.append([0,0.0])
Dcon.append([1.,0])
con.append(Dcon)
### 3.rd Deriv
Dcon=[]
Dcon.append([0,0.0])
Dcon.append([1.,0])
con.append(Dcon)
### 4.th Deriv
Dcon=[]
Dcon.append([0,0.0])
Dcon.append([1.,0])
con.append(Dcon)

p3=tools.polynomial(con)
        
x3=np.linspace(0.,1.,num=100)
y3=np.zeros(len(x3))
y3=p3.evaluate(x3,maxd=6)

sp_free=y3[1][-1]
con=[]
Vcon=[]
# Out:
# number of conditions 9
# order of polynomial function is 8

# %%
plt.figure()
plt.plot(x3,y3[0][:],'x')
plt.figure()
plt.plot(x3,y3[1][:],'x')
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
for i in range (9):
    print "%i %25.20f"%(i,p3.coeffs[i])
# Out:
# 0   -1.00000000000000000000
# 1    0.29999999999999893419
# 2    0.00000000000000000000
# 3    0.00000000000001421085
# 4    0.00000000000000000000
# 5    9.79999999999985682564
# 6  -19.59999999999972075670
# 7   13.99999999999980104803
# 8   -3.49999999999995026201

# %%
xn=0.5
yn=-1.+0.001*xn-9.473903143468002*10**(-15)*xn**3+13.985999999999816*xn**5-27.971999999999607*xn**6+19.979999999999716*xn**7-4.9949999999999291*xn**8
print yn
# Out:
# -0.86291796875

# %%
cd ~/cmg/cases/channel_span/
# Out:
# /home/rp3e11/cmg/cases/channel_span

# %%
x=np.linspace(-1.,1.,num=200)
y=np.cos(0.5*np.pi*x)

# %%
ifile1=open('deriv.dat','r')
nz_h=int(ifile1.readline())
x_h=np.linspace(-1.,1.,num=nz_h)
y_h=np.empty(nz_h)
z_h=np.empty(nz_h)
y_h1=np.empty(nz_h)
for i in range(nz_h):
    temp=ifile1.readline().split()
    x_h[i]=float(temp[0])
    y_h1[i]=float(temp[1])
for i in range(nz_h):
    temp=ifile1.readline().split()
    y_h[i]=float(temp[0])
    z_h[i]=float(temp[1])
z_h1=np.empty(nz_h)
for i in range(nz_h):
    z_h1[i]=float(ifile1.readline())

# %%
plt.figure()
plt.plot(x,y,'--')
plt.plot(x_h,y_h1,'g')
# Out:
# <img src="data:image/png;base64,...">

# %%
z=np.diff(y)/(x[1]-x[0])
z_real=-np.pi/2.*np.sin(np.pi/2*x)

# %%
plt.figure()
plt.plot(x[:-1],z)
plt.plot(x,z_real)
plt.plot(x_h,z_h1)
# Out:
# <img src="data:image/png;base64,...">

# %%
ifile2=open('span_channel_comp.dat','r')
nzp=int(ifile2.readline().split()[0])
data=np.empty([6,nzp])
for i in range(nzp):
    temp=ifile2.readline().split()
    for j in range(6):
        data[j,i]=float(temp[j])

# %%
plt.figure()
plt.plot(data[1,:],data[0,:],label='1.-$x^2$')
plt.plot(data[2,:],data[0,:],label='$ \cos{\left(\\frac{\pi}{2} y\\right)}$')
plt.plot(data[3,:]/max(data[3,:]),data[0,:],label='sim')
plt.xlabel('$u$')
plt.ylabel('$y$')
plt.legend()
plt.grid()
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.figure()
plt.plot(data[4,:],data[0,:],label='$\Delta(sim,1.-x^2)$')
plt.plot(data[5,:],data[0,:],label='$\Delta(sim, \cos{\left(\\frac{\pi}{2} y\\right)})$')
plt.legend()
plt.grid()
# Out:
# <img src="data:image/png;base64,...">
