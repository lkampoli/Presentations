# %%
# %matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import lib_points as lp

# %%
cd ~/drive2/HPT/INLET_TURB_ONLY/
# Out:
# /media/drive2/HPT/INLET_TURB_ONLY

# %%
p_c=lp.point_probe('80_resolution_1/mon_point/point_6.hdf5')
p_bl=lp.point_probe('81_resolution_2/mon_point/point_6.hdf5')
p_f=lp.point_probe('82_resolution_4/mon_point/point_6.hdf5')
# Out:
# Loading monitor point located at -0.6984,-0.0000
# The file contains a time series between nit=5 at time 0.00 and  nit=400000 at time 60.00.
# Span spectras have been collected 20 intervalls from nit 2 to 400001.
# Loading monitor point located at -0.7008, 0.0000
# The file contains a time series between nit=5 at time 0.00 and  nit=160000 at time 24.00.
# Span spectras have been collected 8 intervalls from nit 2 to 160001.
# Loading monitor point located at -0.6996,-0.0000
# The file contains a time series between nit=5 at time 0.00 and  nit=80000 at time 8.00.
# Span spectras have been collected 7 intervalls from nit 2 to 80001.

# %%
p_c.load_time_series(start_time=10,end_time=24)
p_bl.load_time_series(start_time=10,end_time=24)
# Out:
# The data contains invalid entries (probably resulting from inproper writin)g. The series is truncated and now starts at 10.00 and ends at 24.00
# sampling frequency of the dataset is 1333.333333
# The data contains invalid entries (probably resulting from inproper writin)g. The series is truncated and now starts at 10.00 and ends at 24.00
# sampling frequency of the dataset is 1333.333333
# /home/rp3e11/codes/PLATUS_GIT/platus/lib_points.py:205: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if temp_t==None:

# %%
p_c.turb_spec()
p_bl.turb_spec()
# Out:
# The estimates for the standard deviation for the current series are:
# u_1'=0.0523
# u_2'=0.0430
# u_3'=0.0409
# The isotropy of the turbulence is 1.280
# The estimates for the standard deviation for the current series are:
# u_1'=0.0526
# u_2'=0.0438
# u_3'=0.0422
# The isotropy of the turbulence is 1.248

# %%
plt.figure()
plt.loglog(p_c.ts.spec['e_33'])
plt.loglog(p_bl.ts.spec['e_33'])
plt.grid()
# Out:
# <img src="data:image/png;base64,...">

# %%
TI_coarse=np.sqrt((0.0523**2+0.0430**2+0.0409**2)/3.)
TI_bl=np.sqrt((0.0526**2+0.0438**2+0.0422**2)/3.)

# %%
print TI_coarse,TI_bl
# Out:
# 0.0456694646345 0.0464257112672
