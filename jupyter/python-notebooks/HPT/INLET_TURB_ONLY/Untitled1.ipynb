# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib notebook

# %%
import lib_points as lp
import scipy
import numpy as np
import matplotlib.pyplot as plt

# %%
cd ~/cases/INLET_TURB_ONLY/
# Out:
# /home/rp3e11/cases/INLET_TURB_ONLY

# %%
p_thin=lp.point_probe(filename='60_fixed_dom015/mon_point/point_8.hdf5',)
# Out:
# Loading monitor point located at -0.4992,-0.0000
# The file contains a time series between nit=5 at time 0.00 and  nit=200000 at time 30.00.
# Span spectras have been collected 10 intervalls from nit 2 to 200001.

# %%
p_thin.load_span_spec(n_conv=3,start_nit=20000)
# Out:
# performing convergence study for the intervalls:
#    nit 140002 to 200001
#    nit 80002 to 200001
#    nit 20002 to 200001
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
p_1=lp.point_probe(filename='46_dom015/mon_point/point_4.hdf5')
p_1.load_span_spec(n_conv=2)
p_2=lp.point_probe(filename='47_dom02/mon_point/point_4.hdf5')
p_2.load_span_spec(n_conv=2)
p_3=lp.point_probe(filename='48_dom03/mon_point/point_4.hdf5')
p_3.load_span_spec(n_conv=2)
p_4=lp.point_probe(filename='49_dom04/mon_point/point_4.hdf5')
p_4.load_span_spec(n_conv=2)
# Out:
# Loading monitor point located at -0.7000,-0.0016
# The file contains a time series between nit=5 at time 0.00 and  nit=240000 at time 36.00.
# Span spectras have been collected 24 intervalls from nit 2 to 240001.
# performing convergence study for the intervalls:
#    nit 120002 to 240001
#    nit 2 to 240001
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# Loading monitor point located at -0.7000,-0.0016
# The file contains a time series between nit=5 at time 0.00 and  nit=160000 at time 24.00.
# Span spectras have been collected 16 intervalls from nit 2 to 160001.
# performing convergence study for the intervalls:
#    nit 80002 to 160001
#    nit 2 to 160001
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# Loading monitor point located at -0.7000,-0.0016
# ...

# %%
plt.figure()
plt.plot(p_1.sp.corr[1],)
plt.plot(p_2.sp.corr[1])
plt.plot(p_3.sp.corr[1])
plt.plot(p_4.sp.corr[1])
#plt.xlim([0.,10.])
# Out:
# <img src="data:image/png;base64,..." width="640">
