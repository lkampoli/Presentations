# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy

# %%
import lib_points as lp

# %%
cd ~/drive2/HPT/inlet_turb_study/
# Out:
# /media/drive2/HPT/inlet_turb_study

# %%
p1=lp.point_probe('HPT_LS20_DOM80_TI5/mon_point/point_1.hdf5')
p2=lp.point_probe('HPT_LS05_DOM30_TI5/mon_point/point_1.hdf5')
# Out:
# Loading monitor point located at -0.2987, 0.0010
# The file contains a time series between nit=4855103 at time 92.90 and  nit=5244101 at time 101.84.
# Span spectras have been collected 31 intervalls from nit 4855103 to 5244102.
# Loading monitor point located at -0.2987, 0.0010
# The file contains a time series between nit=4505103 at time 84.85 and  nit=5485101 at time 107.39.
# Span spectras have been collected 43 intervalls from nit 4505103 to 5485102.

# %%
p1.load_time_series(start_time=93,end_time=101.5)
p2.load_time_series(start_time=93,end_time=101.5)
# Out:
# The data contains invalid entries (probably resulting from inproper writin)g. The series is truncated and now starts at 93.00 and ends at 101.50
# sampling frequency of the dataset is 21739.130435
# The data contains invalid entries (probably resulting from inproper writin)g. The series is truncated and now starts at 93.00 and ends at 101.50
# sampling frequency of the dataset is 21739.130435

# %%
p1.plot_base_turb()
# Out:
# The estimates for the standard deviation for the current series are:
# u_1'=0.0722
# u_2'=0.0446
# u_3'=0.0429
# The isotropy of the turbulence is 1.684
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
p1.turb_spec(nfft=9192)
p2.turb_spec(nfft=9192)
# Out:
# The estimates for the standard deviation for the current series are:
# u_1'=0.0767
# u_2'=0.0445
# u_3'=0.0461
# The isotropy of the turbulence is 1.725
# The estimates for the standard deviation for the current series are:
# u_1'=0.0731
# u_2'=0.0490
# u_3'=0.0474
# The isotropy of the turbulence is 1.543

# %%
plt.figure()
plt.loglog(p1.ts.spec['f'],p1.ts.spec['e_33'],label='LS20')
plt.loglog(p2.ts.spec['f'],p2.ts.spec['e_33'],label='LS05')
plt.legend()
plt.grid()
plt.xlim([1,10000])
# Out:
# <img src="data:image/png;base64,...">
# (1, 10000)
