# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import lib_subspaces as lsub

# %%
cd ~/drive2/HPT/inlet_turb_study/HPT_LS05_DOM30_TI5/Subspaces/
# Out:
# /media/drive2/HPT/inlet_turb_study/HPT_LS05_DOM30_TI5/Subspaces

# %%
blocks=range(3,5)

start_TS=5405601
stop_TS= 5510601
inc_TS=500
steps=range(start_TS,stop_TS,inc_TS)
tau_w=lsub.subspace('BL_WALL_SH',12,start_TS,blocks,source_folder='./')
tau_w.load_grid()
tau_w.load_data(steps)
# Out:
# The dataset requires 326.535645 Mb of RAM

# %% [markdown]
# # Compute histogram

# %%
tau_w_hist=np.empty([672+383,50])
j=50
bl=0
for j in range(672):
    a=np.histogram(tau_w.data[0][0,:,0,j,:],range=(-0.05,0.0),bins=50,density=True)
    tau_w_hist[j,:]=a[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-020f1c2f7eb2> in <module>()
#       3 bl=0
#       4 for j in range(672):
# ----> 5     a=np.histogram(tau_w.data[0][0,:,0,j,:],bins=50,range=(-0.05,0.0),density=True)
#       6     tau_w_hist[j,:]=a[0]
#
# /usr/local/lib/python2.7/dist-packages/numpy/lib/function_base.pyc in histogram(a, bins, range, normed, weights, density)
#     609                 n.imag += np.bincount(indices, weights=tmp_w.imag, minlength=bins)
#     610             else:
# --> 611                 n += np.bincount(indices, weights=tmp_w, minlength=bins).astype(ntype)
#     612
#     613         # Rename the bin edges for return.
#
# ValueError: The first argument of bincount must be non-negative

# %%
print a[1]
# Out:
# [-0.05  -0.049 -0.048 -0.047 -0.046 -0.045 -0.044 -0.043 -0.042 -0.041
#  -0.04  -0.039 -0.038 -0.037 -0.036 -0.035 -0.034 -0.033 -0.032 -0.031
#  -0.03  -0.029 -0.028 -0.027 -0.026 -0.025 -0.024 -0.023 -0.022 -0.021
#  -0.02  -0.019 -0.018 -0.017 -0.016 -0.015 -0.014 -0.013 -0.012 -0.011
#  -0.01  -0.009 -0.008 -0.007 -0.006 -0.005 -0.004 -0.003 -0.002 -0.001  0.   ]

# %%
plt.plot(a[1][:-1],a[0])
# Out:
# <img src="data:image/png;base64,...">
