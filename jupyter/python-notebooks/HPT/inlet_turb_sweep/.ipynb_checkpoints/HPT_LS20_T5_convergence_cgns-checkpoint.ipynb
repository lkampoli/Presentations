# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib notebook

# %%
#Set up environemnt
import sys
#Append PLATUS libraries if these are not set in your PYTHONPATH 
#sys.path.append('/home/jl12e12/PLATUS/')
#sys.path.append('/home/jl12e12/PLATUS/fortran/lib/')
import lib_hipstar as lh
import tools
import lines as l
import numpy as np
import matplotlib.pyplot as plt
from matplotlib2tikz import save as tikz_save
tikz=True
pdf=True
import os

# %%
inlet_x=-0.5
outlet_x=1.1

# %% [markdown]
# # Load data

# %%
cd ~/HPT_500k/HPT_LS20_DOM80_TI5/convergence/
# Out:
# /mnt/drive2/re_500k/HPT_LS20_DOM80_TI5/convergence

# %%
cases=[]
labels=[]
convergencedir='./'
# now find all the stat-files and set the labels
dt=2.3*1.0e-05
root, dirs, files=next(os.walk(convergencedir))
for d in dirs:
#                self.filelist.append(os.getcwd()+'/'+convergencedir+'/'+d+'/STAT_cont.bin')
    cases.append(convergencedir+'/'+d+'/')
    temp=d.split('_')
    labels.append('%.2f - %.2f'%(float(temp[0])*dt,float(temp[2])*dt))
n_c=len(cases)
print cases
print labels
# Out:
# ['.//5103101_to_5139101/', './/5154101_to_5244101/', './/4965101_to_5045101/', './/4875101_to_4955101/']
# ['117.37 - 118.20', '118.54 - 120.61', '114.20 - 116.04', '112.13 - 113.97']

# %%
cascades=[]
for i in range(n_c):
    filen=cases[i]+'/STAT_cont'
    cascades.append(l.cascade_mean(inlet_x,outlet_x,filename=filen,infile='../cascade3d.in',Refplane='Outlet',chord=1.74
                                  ,HeatTransfer=True,label=labels[i].replace('_',' ')))
# Out:
# reading inlet and outlet
# Reading file in CGNS format
# Extracting line
# Found 198 points.
# Reading file in CGNS format
# Extracting line
# Found 198 points.
# 198
# reading blade
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 672  in block  4 672
# 3 i= 224
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 224  in block  3 224
# 5 i= 224
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 672  in block  5 672
# /home/rp3e11/platus/lines.py:1420: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if self.tang!=None:
# /home/rp3e11/platus/lines.py:1423: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if self.plus_coords!=None:
# /home/rp3e11/platus/lines.py:1425: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if self.cf!=None:
# /home/rp3e11/platus/lines.py:1427: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if self.dist!=None:
# /home/rp3e11/platus/lines.py:2745: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if self.blade.dist!=None:
# 7 i= 224
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 384  in block  7 384
# finished reading blade
# len=1.57321798801
# len=1.57321802527
# dTdn [-112.96301189 -105.18250883 -103.74104923 -107.81076728 -115.16503436]
# mu [  1.13555898e-05   1.13555898e-05   1.13555898e-05   1.13555898e-05
#    1.13555898e-05]
# Reading file in CGNS format
# extract line from (i,j) 1 1  to  1 672  in block  4 672
# /home/rp3e11/platus/lines.py:1560: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if self.len_el==None:
# Reading file in CGNS format
# extract line from (i,j) 223 1  to  223 672  in block  4 672
# Reading file in CGNS format
# extract line from (i,j) 222 1  to  222 672  in block  4 672
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 672  in block  4 672
# reading data from file previously extracted
# Reading file in CGNS format
# extract line from (i,j) 1 1  to  1 224  in block  3 224
# Reading file in CGNS format
# extract line from (i,j) 223 1  to  223 224  in block  3 224
# Reading file in CGNS format
# extract line from (i,j) 222 1  to  222 224  in block  3 224
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 224  in block  3 224
# reading data from file previously extracted
# Reading file in CGNS format
# extract line from (i,j) 1 1  to  1 672  in block  5 672
# Reading file in CGNS format
# extract line from (i,j) 223 1  to  223 672  in block  5 672
# Reading file in CGNS format
# extract line from (i,j) 222 1  to  222 672  in block  5 672
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 672  in block  5 672
# reading data from file previously extracted
# Reading file in CGNS format
# extract line from (i,j) 1 1  to  1 384  in block  7 384
# Reading file in CGNS format
# extract line from (i,j) 223 1  to  223 384  in block  7 384
# Reading file in CGNS format
# extract line from (i,j) 222 1  to  222 384  in block  7 384
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 384  in block  7 384
# reading data from file previously extracted
# reading inlet and outlet
# Reading file in CGNS format
# Extracting line
# Found 198 points.
# Reading file in CGNS format
# Extracting line
# Found 198 points.
# 198
# reading blade
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 672  in block  4 672
# 3 i= 224
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 224  in block  3 224
# 5 i= 224
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 672  in block  5 672
# 7 i= 224
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 384  in block  7 384
# finished reading blade
# len=1.57321798801
# len=1.57321802527
# dTdn [-108.22593927 -100.60681968  -99.38499289 -103.8177691  -111.69218245]
# mu [  1.13555898e-05   1.13555898e-05   1.13555898e-05   1.13555898e-05
#    1.13555898e-05]
# Reading file in CGNS format
# extract line from (i,j) 1 1  to  1 672  in block  4 672
# Reading file in CGNS format
# extract line from (i,j) 223 1  to  223 672  in block  4 672
# Reading file in CGNS format
# extract line from (i,j) 222 1  to  222 672  in block  4 672
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 672  in block  4 672
# reading data from file previously extracted
# Reading file in CGNS format
# extract line from (i,j) 1 1  to  1 224  in block  3 224
# Reading file in CGNS format
# extract line from (i,j) 223 1  to  223 224  in block  3 224
# Reading file in CGNS format
# extract line from (i,j) 222 1  to  222 224  in block  3 224
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 224  in block  3 224
# reading data from file previously extracted
# Reading file in CGNS format
# extract line from (i,j) 1 1  to  1 672  in block  5 672
# Reading file in CGNS format
# extract line from (i,j) 223 1  to  223 672  in block  5 672
# Reading file in CGNS format
# extract line from (i,j) 222 1  to  222 672  in block  5 672
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 672  in block  5 672
# reading data from file previously extracted
# Reading file in CGNS format
# extract line from (i,j) 1 1  to  1 384  in block  7 384
# Reading file in CGNS format
# extract line from (i,j) 223 1  to  223 384  in block  7 384
# Reading file in CGNS format
# extract line from (i,j) 222 1  to  222 384  in block  7 384
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 384  in block  7 384
# reading data from file previously extracted
# reading inlet and outlet
# Reading file in CGNS format
# Extracting line
# Found 198 points.
# Reading file in CGNS format
# Extracting line
# Found 198 points.
# 198
# reading blade
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 672  in block  4 672
# 3 i= 224
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 224  in block  3 224
# 5 i= 224
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 672  in block  5 672
# 7 i= 224
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 384  in block  7 384
# finished reading blade
# len=1.57321798801
# len=1.57321802527
# dTdn [-113.22586767 -108.1797981  -109.18392565 -115.22061494 -124.3336809 ]
# mu [  1.13555898e-05   1.13555898e-05   1.13555898e-05   1.13555898e-05
#    1.13555898e-05]
# Reading file in CGNS format
# extract line from (i,j) 1 1  to  1 672  in block  4 672
# Reading file in CGNS format
# extract line from (i,j) 223 1  to  223 672  in block  4 672
# Reading file in CGNS format
# extract line from (i,j) 222 1  to  222 672  in block  4 672
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 672  in block  4 672
# reading data from file previously extracted
# Reading file in CGNS format
# extract line from (i,j) 1 1  to  1 224  in block  3 224
# Reading file in CGNS format
# extract line from (i,j) 223 1  to  223 224  in block  3 224
# Reading file in CGNS format
# extract line from (i,j) 222 1  to  222 224  in block  3 224
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 224  in block  3 224
# reading data from file previously extracted
# Reading file in CGNS format
# extract line from (i,j) 1 1  to  1 672  in block  5 672
# Reading file in CGNS format
# extract line from (i,j) 223 1  to  223 672  in block  5 672
# Reading file in CGNS format
# extract line from (i,j) 222 1  to  222 672  in block  5 672
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 672  in block  5 672
# reading data from file previously extracted
# Reading file in CGNS format
# extract line from (i,j) 1 1  to  1 384  in block  7 384
# Reading file in CGNS format
# extract line from (i,j) 223 1  to  223 384  in block  7 384
# Reading file in CGNS format
# extract line from (i,j) 222 1  to  222 384  in block  7 384
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 384  in block  7 384
# reading data from file previously extracted
# reading inlet and outlet
# Reading file in CGNS format
# Extracting line
# Found 198 points.
# Reading file in CGNS format
# Extracting line
# Found 198 points.
# 198
# reading blade
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 672  in block  4 672
# 3 i= 224
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 224  in block  3 224
# 5 i= 224
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 672  in block  5 672
# 7 i= 224
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 384  in block  7 384
# finished reading blade
# len=1.57321798801
# len=1.57321802527
# dTdn [-119.99815948 -114.79614094 -115.674752   -121.62105301 -130.6384056 ]
# mu [  1.13555898e-05   1.13555898e-05   1.13555898e-05   1.13555898e-05
#    1.13555898e-05]
# Reading file in CGNS format
# extract line from (i,j) 1 1  to  1 672  in block  4 672
# Reading file in CGNS format
# extract line from (i,j) 223 1  to  223 672  in block  4 672
# Reading file in CGNS format
# extract line from (i,j) 222 1  to  222 672  in block  4 672
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 672  in block  4 672
# reading data from file previously extracted
# Reading file in CGNS format
# extract line from (i,j) 1 1  to  1 224  in block  3 224
# Reading file in CGNS format
# extract line from (i,j) 223 1  to  223 224  in block  3 224
# Reading file in CGNS format
# extract line from (i,j) 222 1  to  222 224  in block  3 224
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 224  in block  3 224
# reading data from file previously extracted
# Reading file in CGNS format
# extract line from (i,j) 1 1  to  1 672  in block  5 672
# Reading file in CGNS format
# extract line from (i,j) 223 1  to  223 672  in block  5 672
# Reading file in CGNS format
# extract line from (i,j) 222 1  to  222 672  in block  5 672
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 672  in block  5 672
# reading data from file previously extracted
# Reading file in CGNS format
# extract line from (i,j) 1 1  to  1 384  in block  7 384
# Reading file in CGNS format
# extract line from (i,j) 223 1  to  223 384  in block  7 384
# Reading file in CGNS format
# extract line from (i,j) 222 1  to  222 384  in block  7 384
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 384  in block  7 384
# reading data from file previously extracted

# %%
cascades[-1].report_integral_mixed_out()

# %% [markdown]
# # Plot cascae quantities
#
# ## Inlet profiles

# %%
ids=[]
ids.append(cascades[0].header.get_index(101,2))
ids.append(cascades[0].header.get_index(101,3))
ids.append(cascades[0].header.get_index(101,10))
ids.append(cascades[0].header.get_index(101,5))
for i,val in enumerate(ids):
    plt.figure()
    for j in range(n_c):
        plt.plot(cascades[j].inlet.data[:,val],cascades[j].inlet.data[:,1],label=cascades[j].label)
    plt.legend()
    plt.xlabel(cascades[j].header.vars[val])
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
inlet_stream=l.lines(convergence=True,convergencedir='./')

# %%
inlet_stream.extr_line([-1.0,0.0],[-0.2,0.0],300)
# Out:
# Reading file in CGNS format
# Extracting line
# Found 300 points.
# Reading file in CGNS format
# Extracting line
# Found 300 points.
# Reading file in CGNS format
# Extracting line
# Found 300 points.
# Reading file in CGNS format
# Extracting line
# Found 300 points.

# %%
pl_var=[]
pl_var.append(inlet_stream.l[0].var.get_index(101,10))
pl_var.append(inlet_stream.l[0].var.get_index(101,2))
inlet_stream.plot_var([0],pl_var)
# Out:
# <div id='327f64a0-e878-49ea-9ef0-faeebcb439e9'></div>
# <div id='ace0b6db-ba17-4209-800c-776299914c74'></div>

# %% [markdown]
# # Blade Profiles

# %%
plt.figure()
for i in range(n_c):
    plt.plot(cascades[i].blade.data[:,0],cascades[i].cp,label=cascades[i].label)
plt.grid()
plt.legend()
plt.xlabel('$C_{ax}$')
plt.ylabel('$c_p$')
# Out:
# <div id='adecb5c3-b2d1-4d69-8ce2-26f6bdc27f48'></div>

# %%
plt.figure()
for i in range(n_c):
    plt.plot(cascades[i].blade.dist[:],cascades[i].qnorm2,label=cascades[i].label)
plt.grid()
plt.legend()
plt.xlabel('$s$')
plt.ylabel('$q_{n}$')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Outlet region

# %%
plt.figure()
for i in range(n_c):
    plt.plot(cascades[i].loss_mix[:],cascades[i].outlet.data[:,1],label=cascades[i].label)
plt.grid()
plt.legend(loc=0)
plt.xlabel('$\omega$')
plt.ylabel('$y$')
# Out:
# <div id='93895092-a086-43ae-a08e-5aaee2d4931b'></div>

# %%
for case_i in cascades:
    case_i.extr_bl_quantities(nps_stream=100,nps_wall_norm=200,extent=0.05,f_ss_start=0.05,f_ss_end=0.95
                           ,f_ps_start=0.02,f_ps_end=0.98)
# Out:
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format
# Reading file in CGNS format

# %%
colors=['b','r','g','k','brown','m']
for j in range(0,100,20):
    plt.figure()
    plt.subplot(1,2,1)
    j_w=5
    plt.title('x=%6.2f,s=%6.2f'%(cascades[0].bl_ss_wall_norm[0,0,j],cascades[0].bl_ss_wall_norm[2,0,j]-0.05))
    for ic in range(3):
        plt.plot(cascades[ic].bl_ss_wall_norm[3,:,j],cascades[ic].bl_ss_wall_norm[1,:,j],label=labels[ic],color=colors[ic])
    plt.grid()
    plt.ylim([0,0.03])
    plt.legend(loc=0)
    plt.xlabel('$u_t$')
    plt.ylabel('$d$')
    plt.subplot(1,2,1)
    j_w=5
    plt.subplot(1,2,2)    
    for ic in range(3):
        plt.plot(-cascades[ic].bl_ss_wall_norm[12,:,j],cascades[ic].bl_ss_wall_norm[1,:,j],label=labels[ic],color=colors[ic])
    plt.grid()
    plt.ylim([0,0.03])
    plt.xlabel('$k$')
    tikz_save('vel_k_prof_%i.tikz'%j,figureheight='\\figureheight',figurewidth='\\figurewidth')
# Out:
# <img src="data:image/png;base64,..." width="640">
# file encoding: None
# =========================================================
# Please add the following line to your LaTeX preamble:
#
# \usepackage{pgfplots}
# \usepgfplotslibrary{groupplots}
# =========================================================
# /usr/local/lib/python2.7/dist-packages/matplotlib/artist.py:233: MatplotlibDeprecationWarning: get_axes has been deprecated in mpl 1.5, please use the
# axes property.  A removal date has not been set.
#   stacklevel=1)
# <img src="data:image/png;base64,..." width="640">
# file encoding: None
# =========================================================
# Please add the following line to your LaTeX preamble:
#
# \usepackage{pgfplots}
# \usepgfplotslibrary{groupplots}
# =========================================================
# <img src="data:image/png;base64,..." width="640">
# file encoding: None
# =========================================================
# Please add the following line to your LaTeX preamble:
#
# \usepackage{pgfplots}
# \usepgfplotslibrary{groupplots}
# =========================================================
# <img src="data:image/png;base64,..." width="640">
# file encoding: None
# =========================================================
# Please add the following line to your LaTeX preamble:
#
# \usepackage{pgfplots}
# \usepgfplotslibrary{groupplots}
# =========================================================
# <img src="data:image/png;base64,..." width="640">
# file encoding: None
# =========================================================
# Please add the following line to your LaTeX preamble:
#
# \usepackage{pgfplots}
# \usepgfplotslibrary{groupplots}
# =========================================================
