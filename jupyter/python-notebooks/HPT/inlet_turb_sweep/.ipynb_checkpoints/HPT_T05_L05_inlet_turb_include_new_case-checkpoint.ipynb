# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import lib_points as lp

# %% [markdown]
# # Reference data from experiment|

# %%
data_arts=np.loadtxt('/home/rp3e11/Documents/HPT/data_spectra.csv',delimiter=',',skiprows=1)
data_font=np.loadtxt('/home/rp3e11/Documents/HPT/data_free_stream_new.csv',delimiter=',',skiprows=1)
c_arts=61.
c_ax_exp=0.036985

# %%
plt.figure()
plt.loglog(data_arts[:,0],data_arts[:,1])
plt.loglog(data_font[:,0],data_font[:,1])
# Out:
# <img src="data:image/png;base64,...">

# %%
cd ~/inlet_turb_study/re_500k/
# Out:
# /media/drive2/HPT/inlet_turb_study

# %%
c_LS5=1.0
c_LS20=1.0
cax_DNS=1.01125574112

# %%
p1_LS5=lp.point_probe('/home/rp3e11/drive2/HPT/inlet_turb_study/HPT_LS05_DOM30_TI5/mon_point/point_1.hdf5')
p1_LS20=lp.point_probe('/home/rp3e11/drive2/HPT/inlet_turb_study/HPT_LS20_DOM80_TI5/mon_point/point_1.hdf5')
p2_LS5=lp.point_probe('/home/rp3e11/drive2/HPT/inlet_turb_study/HPT_LS05_DOM30_TI5/mon_point/point_2.hdf5')
p2_LS20=lp.point_probe('/home/rp3e11/drive2/HPT/inlet_turb_study/HPT_LS20_DOM80_TI5/mon_point/point_2.hdf5')
# Out:
# Loading monitor point located at -0.2987, 0.0010
# The file contains a time series between nit=4505103 at time 84.85 and  nit=5515101 at time 108.08.
# Span spectras have been collected 44 intervalls from nit 4505103 to 5515102.
# Loading monitor point located at -0.2987, 0.0010
# The file contains a time series between nit=4855103 at time 92.90 and  nit=5244101 at time 101.84.
# Span spectras have been collected 31 intervalls from nit 4855103 to 5244102.
# Loading monitor point located at -0.2993,-0.0987
# The file contains a time series between nit=4505103 at time 84.85 and  nit=5515101 at time 108.08.
# Span spectras have been collected 44 intervalls from nit 4505103 to 5515102.
# Loading monitor point located at -0.2993,-0.0987
# The file contains a time series between nit=4855103 at time 92.90 and  nit=5244101 at time 101.84.
# Span spectras have been collected 31 intervalls from nit 4855103 to 5244102.

# %%
p1_LS20.load_time_series(start_time=93,end_time=101.5)
p1_LS5.load_time_series(start_time=93,end_time=101.5)

p2_LS20.load_time_series(start_time=93,end_time=101.5)
p2_LS5.load_time_series(start_time=93,end_time=101.5)
# Out:
# The data contains invalid entries (probably resulting from inproper writing). The series is truncated and now starts at 93.00 and ends at 101.50
# sampling frequency of the dataset is 21739.130435
# The data contains invalid entries (probably resulting from inproper writing). The series is truncated and now starts at 93.00 and ends at 101.50
# sampling frequency of the dataset is 21739.130435
# The data contains invalid entries (probably resulting from inproper writing). The series is truncated and now starts at 93.00 and ends at 101.50
# sampling frequency of the dataset is 21739.130435
# The data contains invalid entries (probably resulting from inproper writing). The series is truncated and now starts at 93.00 and ends at 101.50
# sampling frequency of the dataset is 21739.130435

# %%
p1_LS5.plot_base_turb()
# Out:
# The estimates for the standard deviation for the current series are:
# u_1'=0.0731
# u_2'=0.0490
# u_3'=0.0474
# The isotropy of the turbulence is 1.543
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
p1_LS5.turb_spec(nfft=16384)
p2_LS5.turb_spec(nfft=16384)
p1_LS20.turb_spec(nfft=16384)
p2_LS20.turb_spec(nfft=16384)
# Out:
# The estimates for the standard deviation for the current series are:
# u_1'=0.0672
# u_2'=0.0440
# u_3'=0.0522
# The isotropy of the turbulence is 1.529
# The estimates for the standard deviation for the current series are:
# u_1'=0.0767
# u_2'=0.0445
# u_3'=0.0461
# The isotropy of the turbulence is 1.725
# The estimates for the standard deviation for the current series are:
# u_1'=0.0875
# u_2'=0.0501
# u_3'=0.0566
# The isotropy of the turbulence is 1.746

# %%
var_spec=['e_11','e_22','e_33']
for j in range(3):
    plt.figure()
    plt.loglog(p1_LS5.ts.spec['f'],p1_LS5.ts.spec[var_spec[j]],label='p1 LS5')
    plt.loglog(p2_LS5.ts.spec['f'],p2_LS5.ts.spec[var_spec[j]],label='p2 LS05')
    plt.loglog(p1_LS20.ts.spec['f'],p1_LS20.ts.spec[var_spec[j]],label='p1 LS20')
    plt.loglog(p2_LS20.ts.spec['f'],p2_LS20.ts.spec[var_spec[j]],label='p2 LS20')
    plt.loglog(data_arts[:,0]*c_ax_exp/c_arts,data_arts[:,1],label='Arts')
    plt.loglog(data_font[:,0]*c_ax_exp/c_arts,data_font[:,1]/1000000.,label='Fontanento')    
    plt.legend()
    plt.grid()
    plt.xlim([1,1000])
    plt.ylim([10**(-13),10**(-1)])
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
