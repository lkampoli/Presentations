# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib notebook

# %%
#Set up environemnt
import sys
#Append PLATUS libraries if these are not set in your PYTHONPATH 
#sys.path.append('/home/jl12e12/PLATUS/')
#sys.path.append('/home/jl12e12/PLATUS/fortran/lib/')
import lib_hipstar as lh
import tools
import lines as l
import numpy as np
import matplotlib.pyplot as plt
from matplotlib2tikz import save as tikz_save
tikz=True
pdf=True
import os

# %%
inlet_x=-0.5
outlet_x=1.1

# %%
cd ~/HPT_500k/HPT_LS05_DOM30_TI5/
# Out:
# /mnt/drive2/re_500k/HPT_LS05_DOM30_TI5

# %%
casc=l.cascade_mean(inlet_x,outlet_x,filename='convergence/4645101_to_5515101/STAT_cont',infile='cascade3d.in'
                    ,Refplane='Outlet',chord=1.74)
casc_ref=l.cascade_mean(inlet_x,outlet_x,filename='convergence/4645101_to_5515101/STAT_cont',infile='cascade3d.in'
                    ,Refplane='Outlet',chord=1.74)
# Out:
# reading inlet and outlet
# Reading file in CGNS format
# reading data from file previously extracted
# Reading file in CGNS format
# reading data from file previously extracted
# 198
# reading blade
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 672  in block  4 672
# reading data from file previously extracted
# 3 i= 224
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 224  in block  3 224
# reading data from file previously extracted
# 5 i= 224
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 672  in block  5 672
# reading data from file previously extracted
# 7 i= 224
# Reading file in CGNS format
# extract line from (i,j) 224 1  to  224 384  in block  7 384
# reading data from file previously extracted
# finished reading blade
# len=1.57321798801
# len=1.57321802527
# dTdn [-112.83270171 -104.79215762 -103.39782521 -107.78654592 -115.67090007]
# ...

# %%
plt.figure()
plt.plot(casc.blade.data[:,0],casc.cp)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(casc.blade.data[:,0],casc.blade.cf)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(casc.outlet.data[:,0],casc.loss_mix)
# Out:
# <img src="data:image/png;base64,..." width="640">
