# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib notebook

# %%
#Set up environemnt
import sys
#Append PLATUS libraries if these are not set in your PYTHONPATH 
#sys.path.append('/home/jl12e12/PLATUS/')
#sys.path.append('/home/jl12e12/PLATUS/fortran/lib/')
import lib_hipstar as lh
import tools
import lines as l
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors
from matplotlib2tikz import save as tikz_save
tikz=True
pdf=True
import os

# %%
cd ~/HPT_500k/
# Out:
# /mnt/drive2/re_500k

# %%
import planes

# %%
domain=planes.plane()
domain.read_data('HPT_LS05_DOM30_TI5/case_sel/STAT_cont','HPT_LS05_DOM30_TI5/cascade3d.in')
# Out:
# HPT_LS05_DOM30_TI5/case_sel/STAT_cont
# Reading file in CGNS format

# %%
domain.extr_plane([3,4,5])

# %%
blade_coord=domain.extract_curve(i_const=224,blocks=[3,2,4,6])

# %%
domain.turn_plane(blade_coord,5,6,save_tang=True)

# %%
plt.figure()
plt.axes(aspect=1)
for j in [2,3,4,6]:
    clb=plt.contourf(domain.grid[j][:,:,0],domain.grid[j][:,:,1],domain.turned_field[j][:,:,2])
    #plt.quiver(domain.grid[j][::5,::5,0],domain.grid[j][::5,::5,1]
    #           ,domain.turned_field[j][::5,::5,3],domain.turned_field[j][::5,::5,4]
    #           ,scale=5)
#plt.colorbar(cb=clb)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
levs=np.linspace(-7,2,num=13)
plt.figure()
plt.axes(aspect=1)
for j in [2,3,4,6]:
    clb=plt.contourf(domain.grid[j][:,:,0],domain.grid[j][:,:,1],domain.field[j][:,:,2],levels=levs)
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
levs=np.linspace(-7,7.,num=150)
plt.figure()
plt.axes(aspect=1)
for j in [2,3,4,6]:
    clb=plt.contourf(domain.grid[j][:,:,0],domain.grid[j][:,:,1],domain.turned_field[j][:,:,0],levels=levs)
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
for ib in range(9):
    plt.contourf(domain.grid[ib][:,:,0],domain.grid[ib][:,:,1],domain.field[ib][:,:,1],levels=np.linspace(-0.5,2.0,num=26)
                ,extend='max')
# Out:
# <img src="data:image/png;base64,..." width="640">
