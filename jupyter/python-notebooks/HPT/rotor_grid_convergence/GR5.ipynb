# %%
# %matplotlib inline

# %%
# %config InlineBackend.figure_format = 'svg'

# %%
#First things first change to your working directory containing your HiPSTAR case
import os
os.chdir('/home/rp3e11/drive1/HPT/rotor_cases/GR5/')
casedir=os.getcwd()

# %%
#Set up environemnt
import sys
#Append PLATUS libraries if these are not set in your PYTHONPATH 
#sys.path.append('/home/jl12e12/PLATUS/')
#sys.path.append('/home/jl12e12/PLATUS/fortran/lib/')
import lib_hipstar as lh
import tools
import lines as l
import numpy as np
import matplotlib.pyplot as plt
from matplotlib2tikz import save as tikz_save
tikz=True
pdf=True

# %%
folders=['convergence/2200101_to_2580101/','convergence/2440101_to_2580101/']


cascades=[]
for fold in folders:
    cascades.append(l.cascade_mean(-0.3,1.26,filename='%s/STAT_cont.bin'%fold,
                                   infile='cascade.in',Refplane='Outlet',chord=1.05))
# Out:
# reading data from file previously extracted
# reading data from file previously extracted
# extract line from (i,j) 121 1  to  121 409  in block  4 409
# reading data from file previously extracted
# 11
# extract line from (i,j) 121 1  to  121 81  in block  3 81
# reading data from file previously extracted
# 11
# extract line from (i,j) 121 1  to  121 409  in block  5 409
# reading data from file previously extracted
# 11
# extract line from (i,j) 121 1  to  121 161  in block  7 161
# reading data from file previously extracted
# 11
# /home/rp3e11/codes/platus/lines.py:1318: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if self.tang!=None:
# /home/rp3e11/codes/platus/lines.py:1321: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if self.plus_coords!=None:
# /home/rp3e11/codes/platus/lines.py:1323: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if self.cf!=None:
# /home/rp3e11/codes/platus/lines.py:1421: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if self.len_el==None:
# reading data from file previously extracted
# reading data from file previously extracted
# extract line from (i,j) 121 1  to  121 409  in block  4 409
# reading data from file previously extracted
# 11
# extract line from (i,j) 121 1  to  121 81  in block  3 81
# reading data from file previously extracted
# 11
# extract line from (i,j) 121 1  to  121 409  in block  5 409
# reading data from file previously extracted
# 11
# extract line from (i,j) 121 1  to  121 161  in block  7 161
# reading data from file previously extracted
# 11
# /home/rp3e11/codes/platus/lines.py:1359: RuntimeWarning: invalid value encountered in double_scalars
#   self.nondim[i]=(self.data[i,index]-self.data[0,index])/len_line

# %%
plt.figure()
for cascade in cascades:
    plt.plot(cascade.blade.data[:,0],cascade.cp)
plt.grid()
plt.xlabel('$x$')
plt.ylabel('$c_p= \\frac{p(x)-p_{out}}{p_{t,in}-p_{out}}$')
tikz_save("cp_blade.tikz",
              figureheight = '\\fh',
              figurewidth = '\\fw')
# Out:
# file encoding: None
# =========================================================
# Please add the following line to your LaTeX preamble:
#
# \usepackage{pgfplots}
# =========================================================

# %%
plt.figure()
for cascade in cascades:
    plt.plot(cascade.loss_mix,cascade.outlet.data[:,1])
plt.grid()
plt.ylabel('$x$')
plt.xlabel('$\omega= \\frac{p_{t,in}-p_{t,out}(y)}{p_{t,in}-p_{out}}$')
tikz_save("wake_loss.tikz",
          figureheight = '\\fh',
          figurewidth = '\\fw')
# Out:
# file encoding: None
# =========================================================
# Please add the following line to your LaTeX preamble:
#
# \usepackage{pgfplots}
# =========================================================

# %%
cascade.report_integral_mixed_out()
# Out:
# Isentropic Reynolds Number:    259439.40570
# Isentropic Mach Number:    0.7139877563
# Isentropic Reynolds Number:    266225.00419 (inlet mass averaged)
# Isentropic Mach Number:    0.7139866930 (inlet mass averaged)
# Isentropic exit Velocity:    2.7947062762
# Mixed out loss    0.0503675858
# Inlet angle:  -31.0075013892
# Inlet Mach number:    0.2394339661
# Inlet stagnation pressure:   12.9653435887
# Inlet stagnation Temperature:    1.1025569889
# Inlet static pressure:   12.4581895202
# Inlet static Temperature:    1.0900586761
# Outlet angle:   67.6176713758
# Outlet Mach number:    0.6977224451
# Outlet stagnation pressure:   12.7772117532
# Outlet stagnation Temperature:    1.1003666266
# Outlet static pressure:    9.2301668347
# Outlet static Temperature:    1.0027368370
# Outlet density:    0.8054352530

# %%
plt.figure()
index=cascade.inlet.var.get_index(119,4)
for cascade in cascades:

    plt.plot(cascade.inlet.data[:,index],cascade.inlet.data[:,1])
plt.grid()
plt.ylabel('$x$')
plt.xlabel('$TI$')
tikz_save("wake_loss.tikz",
              figureheight = '\\fh',
              figurewidth = '\\fw')
# Out:
# file encoding: None
# =========================================================
# Please add the following line to your LaTeX preamble:
#
# \usepackage{pgfplots}
# =========================================================
