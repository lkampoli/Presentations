# %%
# %matplotlib inline

# %%
# %config InlineBackend.figure_format = 'svg'

# %%
#First things first change to your working directory containing your HiPSTAR case
import os
os.chdir('/home/rp3e11/drive1/HPT/rotor_cases/GR4/')
casedir=os.getcwd()

# %%
#Set up environemnt
import sys
#Append PLATUS libraries if these are not set in your PYTHONPATH 
#sys.path.append('/home/jl12e12/PLATUS/')
#sys.path.append('/home/jl12e12/PLATUS/fortran/lib/')
import lib_hipstar as lh
import tools
import lines as l
import numpy as np
import matplotlib.pyplot as plt
from matplotlib2tikz import save as tikz_save
tikz=True
pdf=True

# %%
folders=['convergence/2668101_to_2848101/','convergence/2428101_to_2848101/']


cascades=[]
for fold in folders:
    cascades.append(l.cascade_mean(-0.3,1.26,filename='%s/STAT_cont.bin'%fold,
                                   infile='cascade.in',Refplane='Outlet',chord=1.05))
# Out:
# reading data from file previously extracted
# reading data from file previously extracted
# extract line from (i,j) 193 1  to  193 817  in block  4 817
# reading data from file previously extracted
# 11
# extract line from (i,j) 193 1  to  193 161  in block  3 161
# reading data from file previously extracted
# 11
# extract line from (i,j) 193 1  to  193 817  in block  5 817
# reading data from file previously extracted
# 11
# extract line from (i,j) 193 1  to  193 321  in block  7 321
# reading data from file previously extracted
# 11
# Extracting line
# Found 197 points.
# Extracting line
# Found 197 points.
# extract line from (i,j) 193 1  to  193 817  in block  4 817
# 11
# extract line from (i,j) 193 1  to  193 161  in block  3 161
# 11
# extract line from (i,j) 193 1  to  193 817  in block  5 817
# 11
# extract line from (i,j) 193 1  to  193 321  in block  7 321
# 11

# %%
plt.figure()
for cascade in cascades:

    plt.plot(cascade.blade.data[:,0],cascade.cp)
plt.grid()
plt.xlabel('$x$')
plt.ylabel('$c_p= \\frac{p(x)-p_{out}}{p_{t,in}-p_{out}}$')
tikz_save("cp_blade.tikz",
              figureheight = '\\fh',
              figurewidth = '\\fw')
# Out:
# file encoding: None
# =========================================================
# Please add the following line to your LaTeX preamble:
#
# \usepackage{pgfplots}
# =========================================================

# %%
plt.figure()
for cascade in cascades:

    plt.plot(cascade.loss_mix,cascade.outlet.data[:,1])
plt.grid()
plt.ylabel('$x$')
plt.xlabel('$\omega= \\frac{p_{t,in}-p_{t,out}(y)}{p_{t,in}-p_{out}}$')
tikz_save("wake_loss.tikz",
              figureheight = '\\fh',
              figurewidth = '\\fw')
# Out:
# file encoding: None
# =========================================================
# Please add the following line to your LaTeX preamble:
#
# \usepackage{pgfplots}
# =========================================================

# %%
cascade.report_integral_mixed_out()
# Out:
# Isentropic Reynolds Number:    259700.06024
# Isentropic Mach Number:    0.7160809573
# Isentropic Reynolds Number:    266647.12613 (inlet mass averaged)
# Isentropic Mach Number:    0.7160797065 (inlet mass averaged)
# Isentropic exit Velocity:    2.8094750683
# Mixed out loss    0.0456824438
# Inlet angle:  -30.9935090204
# Inlet Mach number:    0.2397173449
# Inlet stagnation pressure:   12.9407062657
# Inlet stagnation Temperature:    1.1010199896
# Inlet static pressure:   12.4333475192
# Inlet static Temperature:    1.0885098750
# Outlet angle:   67.6681000225
# Outlet Mach number:    0.7013177243
# Outlet stagnation pressure:   12.7695992171
# Outlet stagnation Temperature:    1.1016639601
# Outlet static pressure:    9.1951306252
# Outlet static Temperature:    1.0029995831
# Outlet density:    0.8021677608
