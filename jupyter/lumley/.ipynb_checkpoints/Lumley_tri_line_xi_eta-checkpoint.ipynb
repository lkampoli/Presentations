# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
import lib_read_HiPSTAR as rf
import lib_VTK as vtk
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # wake line

# %%
#alpha1 = np.arctan((-1.44001+1.72454)/(1.01424-1.11261))
alpha1 = np.arctan((-1.47673+1.68529)/(0.997596-1.06985))
print alpha1
alpha = np.rad2deg(alpha1)
print alpha
# Out:
# -1.23729448581
# -70.8917520519

# %%
#set location of TE, and wake angle
x1=1.0
y1=-1.43
len_line=0.8  # length of line
np_line=600   #number of points on line
x2 = x1+0.2*np.cos(np.deg2rad(alpha))
y2 = y1+0.2*np.sin(np.deg2rad(alpha))
x3 = x1+1.0*np.cos(np.deg2rad(alpha))
y3 = y1+1.0*np.sin(np.deg2rad(alpha))
print x2,y2
print x3,y3
x = np.linspace(x2, x3)
y = np.linspace(y2, y3)
z = 0.0
# Out:
# 1.06547078492 -1.61898035962
# 1.32735392462 -2.37490179809

# %% [markdown]
# # function

# %%
import numpy as np 

def xi_eta(stress):
    """
    stress is a numpy array of 6 components
    a11, a22, a33, a12, a13, a23
    """
    a11 = stress[0]
    a22 = stress[1]
    a33 = stress[2]
    a12 = stress[3]
    a13 = stress[4]
    a23 = stress[5]

    I1 = a11 + a22 + a33
    I2 = a11*a22 + a22*a33 + a11*a33 \
         -a12*a12 - a23*a23 - a13*a13
    I3 = -a13*a22*a13 + a12*a23*a13 + a13*a12*a23 \
         -a11*a23*a23 - a12*a12*a33 + a11*a22*a33

    xi = (I3/2.0)**(1.0/3.0)
    eta = (-0.5*I2)**0.5
    
    Is = np.asarray([xi,eta])
    return(Is)

def list_xi_eta(stresses):
    """
    stresses is a list of stress;
    stress is a numpy array of 6 components
    a11, a22, a33, a12, a13, a23
    """
    n = len(stresses)
    inv = []
    for i in range(n):
        inv.append(invariants(stresses[i]))

    return(inv)

def xi_eta_bound():

    p0 = [0.0, 0.0]
    p1 = [-1.0/6.0, 1.0/6.0]
    p2 = [1.0/3.0, 1.0/3.0]

    l1 = []
    l2 = []
    l3 = []

    x1 = np.linspace(p0[0], p2[0])
    x2 = np.linspace(p2[0], p1[0])
    x3 = np.linspace(p0[0], p1[0])

    y1 = x1
    y2 = (1.0/27.0 + 2.0*x2**3.0)**0.5
    y3 = -x3

    l1.append(x1)
    l1.append(y1)
    l2.append(x2)
    l2.append(y2)
    l3.append(x3)
    l3.append(y3)

    return(l1,l2,l3)

# %% [markdown]
# # Hip VTK

# %%
# read hipstar data into vtk object, need to output data into .vtk by paraview first!
hip_vtk = vtk.read_VTK_dataset('vtk/LS5TI5.vtk')

# %%
#list the vars to be outputed
nvar_source = hip_vtk.GetPointData().GetNumberOfArrays()
print nvar_source
var_list = []
for i in range(nvar_source):
    temp_var = hip_vtk.GetPointData().GetArrayName(i)
#    print i,temp_var
    var_list.append(temp_var)
#lines = [line.rstrip('\n') for line in open('vtk/header.txt')]
#print lines
print var_list
# Out:
# 7
# ['$ \\overline{\\rho}$', '$ \\tau_{11}$', '$ \\tau_{12}$', '$ \\tau_{13}$', '$ \\tau_{22}$', '$ \\tau_{23}$', '$ \\tau_{33}$']

# %%
HiP_stress_line = []
for i in range(len(x)):
    pt = [x[i],y[i],z]
    _, data = vtk.extract_VTK_point(hip_vtk,pt)

    # Hipstar uses negative stress convention
    rho = data[0][1][0][0]
    Rxx = -data[1][1][0][0]
    Rxy = -data[2][1][0][0]
    Rxz = -data[3][1][0][0]
    Ryy = -data[4][1][0][0]
    Ryz = -data[5][1][0][0]
    Rzz = -data[6][1][0][0]
    
    tke = 0.5*(Rxx + Ryy + Rzz)

    HiP_stress_line.append(np.asarray([Rxx/2.0/tke-1.0/3.0,Ryy/2.0/tke-1.0/3.0,Rzz/2.0/tke-1.0/3.0,Rxy,Rxz,Ryz]))

# %%
HiP_inv_line = list_invariants(HiP_stress_line)
print HiP_inv_line.shape
# Out:
# (50, 3)

# %% [markdown]
# # Lumley

# %%
l1,l2,l3 = lumley_tri()

# %% [markdown]
# # RANS Baseline

# %%
# read hipstar data into vtk object, need to output data into .vtk by paraview first!
baseline_vtk = vtk.read_VTK_dataset('vtk/RANS_baseline.vtk')
#list the vars to be outputed
nvar_source = baseline_vtk.GetPointData().GetNumberOfArrays()
print nvar_source
var_list = []
for i in range(nvar_source):
    temp_var = baseline_vtk.GetPointData().GetArrayName(i)
#    print i,temp_var
    var_list.append(temp_var)
#lines = [line.rstrip('\n') for line in open('vtk/header.txt')]
#print lines
print var_list
# Out:
# 13
# ['Momentum', 'Density', 'Function0', 'Function1', 'Function2', 'Function3', 'Function4', 'Function5', 'Function6', 'Function7', 'Function8', 'Pressure', 'StagnationEnergy']

# %%
baseline_stress_line = []
for i in range(len(x)):
    pt = [x[i],y[i],z]
    _, data = vtk.extract_VTK_point(baseline_vtk,pt)

    # Hipstar uses negative stress convention
    rho = data[1][1][0][0]
    tke = data[9][1][0][0]
    Rxx = -data[2][1][0][0]/rho/tke/2.0
    Rxy = -data[3][1][0][0]/rho/tke/2.0
    Ryy = -data[4][1][0][0]/rho/tke/2.0
    Rxz = 0.0
    Ryz = 0.0
    Rzz = -(Rxx + Ryy)

    baseline_stress_line.append(np.asarray([Rxx,Ryy,Rzz,Rxy,Rxz,Ryz]))

# %%
baseline_inv_line = list_invariants(baseline_stress_line)
print baseline_inv_line.shape
# Out:
# (50, 3)

# %% [markdown]
# # GEP Model

# %%
# read hipstar data into vtk object, need to output data into .vtk by paraview first!
inloop_vtk = vtk.read_VTK_dataset('vtk/RANS_inloop.vtk')
#list the vars to be outputed
nvar_source = inloop_vtk.GetPointData().GetNumberOfArrays()
print nvar_source
var_list = []
for i in range(nvar_source):
    temp_var = inloop_vtk.GetPointData().GetArrayName(i)
#    print i,temp_var
    var_list.append(temp_var)
#lines = [line.rstrip('\n') for line in open('vtk/header.txt')]
#print lines
print var_list
# Out:
# 13
# ['Momentum', 'Density', 'Function0', 'Function1', 'Function2', 'Function3', 'Function4', 'Function5', 'Function6', 'Function7', 'Function8', 'Pressure', 'StagnationEnergy']

# %%
inloop_stress_line = []
for i in range(len(x)):
    pt = [x[i],y[i],z]
    _, data = vtk.extract_VTK_point(inloop_vtk,pt)

    # Hipstar uses negative stress convention
    rho = data[1][1][0][0]
    tke = data[9][1][0][0]
    tau_xx = -data[2][1][0][0]/rho/tke/2.0
    tau_xy = -data[3][1][0][0]/rho/tke/2.0
    tau_yy = -data[4][1][0][0]/rho/tke/2.0
    
    a_xx = data[6][1][0][0]/rho/tke/2.0
    a_xy = data[7][1][0][0]/rho/tke/2.0
    a_yy = data[8][1][0][0]/rho/tke/2.0
    
    Rxx = a_xx + tau_xx 
    Rxy = a_xy + tau_xy 
    Ryy = a_yy + tau_yy 
    #Rxx = tau_xx 
    #Rxy = tau_xy 
    #Ryy = tau_yy 
    Rxz = 0.0
    Ryz = 0.0
    Rzz = -(Rxx + Ryy)
    #Rzz = -(tau_xx + tau_yy)
    #print rho,tke,a_xx
    inloop_stress_line.append(np.asarray([Rxx,Ryy,Rzz,Rxy,Rxz,Ryz]))

# %%
inloop_inv_line = list_invariants(inloop_stress_line)
print inloop_inv_line.shape
# Out:
# (50, 3)

# %%
plt.figure()
#plt.axes(aspect='equal')
plt.plot(l1[0],-l1[1],'k-',label='Lumley')
plt.plot(l2[0],-l2[1],'k-')
plt.plot(l3[0],-l3[1],'k-')
plt.plot(HiP_inv_line[:,2],-HiP_inv_line[:,1],'ro',markersize=3,label='LES')
plt.plot(baseline_inv_line[:,2],-baseline_inv_line[:,1],'bo',markersize=3,label='RANS Baseline')
plt.plot(inloop_inv_line[:,2],-inloop_inv_line[:,1],'go',markersize=3,label='RANS Inloop')
#plt.xlim(-0.01,0.01)
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
case = 'LS5_TI5' # LS20_TI20
file_path = '/mnt/drive1/yaomin/HPT-midspan-Sfiles/HPT_500k_'+case+'/post_pro-rp/'

# %%
var = [9,10,11,12,13,14, 16,17,22, 0,5]
block_ids = [4,5,6,7,8,9]
grid = rf.get_grids_stat_xmf(wdir=file_path,block_ids=block_ids,PRINT=True,subvol=None,\
                          stat_xmf='STAT.xmf',stat_bin='STAT_cont.bin')
# Out:
# Global dimensions: 224, 672, 1 ==> 150528
# Subset dimensions: 224, 672, 1 ==> 150528
# Global dimensions: 224, 672, 1 ==> 150528
# Subset dimensions: 224, 672, 1 ==> 150528
# Global dimensions: 224, 672, 1 ==> 150528
# Subset dimensions: 224, 672, 1 ==> 150528
# Global dimensions: 224, 384, 1 ==> 86016
# Subset dimensions: 224, 384, 1 ==> 86016
# Global dimensions: 224, 384, 1 ==> 86016
# Subset dimensions: 224, 384, 1 ==> 86016
# Global dimensions: 224, 224, 1 ==> 50176
# Subset dimensions: 224, 224, 1 ==> 50176
# 0  \overline{\rho}
# 1  \widetilde{u_1}
# 2  \widetilde{u_2}
# 3  \widetilde{T}
# 4  \overline{p}
# 5  \overline{\mu}
# 6  \rho'
# 7  T'
# 8  p'
# 9  \tau_{11}
# 10  \tau_{12}
# 11  \tau_{22}
# 12  \tau_{33}
# 13  \tau_{13}
# 14  \tau_{23}
# 15  \widetilde{u_3}
# 16  \overline{u_1}
# 17  \overline{u_2}
# 18  \overline{T}
# 19  \overline{T^'}
# 20  \overline{u_1^'}
# 21  \overline{u_2^'}
# 22  \overline{u_3}
# 23  \overline{u_3^'}
# 24 P_{11}
# 25 P_{12}
# 26 P_{22}
# 27 P_{33}
# 28 T_{u,11}
# 29 T_{u,12}
# 30 T_{u,22}
# 31 T_{u,33}
# 32 T_{p,11}
# 33 T_{p,12}
# 34 T_{p,22}
# 35 T_{p,33}
# 36 T_{t,11}
# 37 T_{t,12}
# 38 T_{t,22}
# 39 T_{t,33}
# 40 R_{11}
# 41 R_{12}
# 42 R_{22}
# 43 R_{33}
# 44 \Pi_{11}
# 45 \Pi_{12}
# 46 \Pi_{22}
# 47 \Pi_{33}
# 48 \Nu_{11}
# 49 \Nu_{12}
# 50 \Nu_{22}
# 51 \Nu_{33}
# 52 \epsilon_{11}
# 53 \epsilon_{12}
# 54 \epsilon_{22}
# 55 \epsilon_{33}
# 56 _1'T
# 57 _2'T
# 58 _3'T
# 59 P
# 60 T_1
# 61 T_2
# 62 T_3
# 63 R
# 64  \Pi
# 65  \mathcal{V}
# 66  \overline{\rho}\epsilon
# 67  \frac{\partial \widetilde{u}_{1}}{\partial x_1}
# 68  \frac{\partial \widetilde{u}_{1}}{\partial x_2}
# 69  \frac{\partial \widetilde{u}_{2}}{\partial x_1}
# 70  \frac{\partial \widetilde{u}_{2}}{\partial x_2}
# 71  \frac{\partial \widetilde{T}}{\partial x_1}
# 72  \frac{\partial \widetilde{T}}{\partial x_2}
# 73  \frac{\partial \overline{p}}{\partial x_1}
# 74  \frac{\partial \overline{p}}{\partial x_2}
# 75  \frac{\partial \overline{u}_{1}{\partial x_1}
# 76  \frac{\partial \overline{u}_{1}}{\partial x_2}
# 77  \frac{\partial \overline{u}_{2}}{\partial x_1}
# 78  \frac{\partial \overline{u}_{2}}{\partial x_2}
# 79  S_{12}\left(\widetilde{u}\right)
# 80  \Omega_{12}\left(\widetilde{u}\right)
# 81  S_{12}\left(\overline{u}\right)
# 82  \Omega_{12}\left(\overline{u}\right)
# 83  t_{11}\left(\widetilde{u}\right)
# 84  t_{12}\left(\widetilde{u}\right)
# 85  t_{22}\left(\widetilde{u}\right)
# 86  t_{11}\left(\overline{u}\right)
# 87  t_{12}\left(\overline{u}\right)
# 88  t_{22}\left(\overline{u}\right)
# 89  t_{11}\left(\overline{u^{}}\right)
# 90  t_{12}\left(\overline{u^{}}\right)
# 91  t_{22}\left(\overline{u^{}}\right)
# 92  \mu_{sgs}
# 93  m_{\tau,1}
# 94  m_{\tau,2}
# 95  e_{t,kin}
# 96  e_{t,h}
# 97  e_{t,\widetilde{u}}
# 98  e_{t,\tau}
# 99  e_{t,u}
# 100  e_{t,\widetilde{T}}
# 101  e_{t,T}
# 102  e_{t,h}
# 103  e_{t,k}
# 104  r_{TKE}
# 105  r_{et}
