# %% [markdown]
# # A quick demo on how to install PLATUS, in particular the lines library function

# %% [markdown]
# Navigate to the folder where the library is stored and compile it using the make commands. f2py and gfortran have to be installed on the system.

# %%
cd /home/yaomin/development/PLATUS/fortran/source
# Out:
# /home/yaomin/development/PLATUS/fortran/source

# %%
# %%bash
# make gnu -j && make install
# Out:
# make	"PLATUS"  \
# 	"FC=gfortran" \
# 	"FCMPI=mpif90" \
# 	"FFLAGS=-fPIC -O2 " \
# 	"LIBS=-L/usr/lib/x86_64-linux-gnu/hdf5/openmpi -lhdf5_fortran -lhdf5 -lhdf5hl_fortran -lhdf5_hl -llapack -lblas" \
# 	"INCL= -I/usr/include/hdf5/openmpi/ -I/usr/include/"
# make[1]: Entering directory '/home/yaomin/development/PLATUS/fortran/source'
# sed -i '/^$/d' read_input.f
# f2py -c read_input.f -m read_input err_info.o stopnow.o mppvars.o read_line.o  -L/usr/lib/x86_64-linux-gnu/hdf5/openmpi -lhdf5_fortran -lhdf5 -lhdf5hl_fortran -lhdf5_hl -llapack -lblas
# running build
# running config_cc
# unifing config_cc, config, build_clib, build_ext, build commands --compiler options
# running config_fc
# unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
# running build_src
# build_src
# building extension "read_input" sources
# f2py options: []
# f2py:> /tmp/tmpL67hsQ/src.linux-x86_64-2.7/read_inputmodule.c
# creating /tmp/tmpL67hsQ/src.linux-x86_64-2.7
# ...

# %%
# Out:
# mkdir -p ../lib
# mv *.so ../lib
# Makefile:17: recipe for target 'install' failed
# mv: cannot stat '*.so': No such file or directory
# make: *** [install] Error 1

# %% [markdown]
# "make all" first compiles the fortran routines and then generates the wrapper. Make install moves it into the lib subfolder which has to be added to the python path in ~/.bashrc
