# %%
# %matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt
import tools

# %%
# wall spacing blade
nxp_p=np.array([    0.06317555863648920134   ,  0.15387840527645010869])
nxp_pm1=np.array([    0.06328761062334230247  ,   0.15379203379380579353])
a=np.sqrt((nxp_p[0]-nxp_pm1[0])**2+(nxp_p[1]-nxp_pm1[1])**2)
print a,5.*a
# Out:
# 0.000141476785276 0.000707383926378

# %%
np_bl=65
bl_thick=0.15
span=2.0
spacing_wall=0.0004

# %%
sp_half=span/2.

# %%
#span spacing in simulations with homogenous span
print 0.2/100.
# Out:
# 0.002

# %%
con=[]
Vcon=[]
### Value constraints
Vcon.append([1,0.0])
Vcon.append([np_bl,bl_thick])
con.append(Vcon)
### 1.st Derivative/spacing constraint
Dcon=[]
Dcon.append([1,spacing_wall])
con.append(Dcon)
### 2.nd Deriv
Dcon=[]
Dcon.append([1,0.0])
Dcon.append([np_bl,0])
con.append(Dcon)
### 3.rd Deriv
Dcon=[]
Dcon.append([1,0.0])
Dcon.append([np_bl,0])
con.append(Dcon)
### 4.th Deriv
Dcon=[]
Dcon.append([1,0.0])
Dcon.append([np_bl,0])
con.append(Dcon)

p3=tools.polynomial(con)
        
x3=range(1,Vcon[-1][0]+1)
y3=np.zeros(len(x3))
y3=p3.evaluate(x3,maxd=6)

sp_free=y3[1][-1]
np_free=int((span/2.-bl_thick)/sp_free)+1
print 'spacing at wall and in freestream ',y3[1][0],y3[1][-1]
print 'Points in free stream ',np_free
con=[]
Vcon=[]
### Value constraints
Vcon.append([1,bl_thick])
Vcon.append([np_free,span/2])
con.append(Vcon)
### 1.st Derivative/spacing constraint
Dcon=[]
Dcon.append([1,sp_free])
con.append(Dcon)
### 2.nd Deriv
Dcon=[]
Dcon.append([1,0.0])
Dcon.append([np_free,0])
con.append(Dcon)
## 3rd Deriv
Dcon=[]
Dcon.append([1,0.0])
Dcon.append([np_free,0])
con.append(Dcon)

## 4th Deriv
Dcon=[]
Dcon.append([1,0.0])
Dcon.append([np_free,0])
con.append(Dcon)

p4=tools.polynomial(con)
x4=range(1,Vcon[-1][0]+1)
y4=np.zeros(len(x4))
y4=p4.evaluate(x4,maxd=6)


print 'maximum spacing and ratio between highest and gen spacing', max(y3[1][:]), max(y3[1][:])/y3[1][0] 
print 'maximum spacing and ratio between highest and gen spacing', max(y3[1]), min(y3[1]) 
print
# Out:
# number of conditions 9
# order of polynomial function is 8
# spacing at wall and in freestream  0.0004 0.0042875
# Points in free stream  199
# number of conditions 9
# order of polynomial function is 8
# maximum spacing and ratio between highest and gen spacing 0.0042875 10.71875
# maximum spacing and ratio between highest and gen spacing 0.0042875 0.0004

# %%
n_tot=2*np_bl+np_free*2-3
grid=np.empty(n_tot)
for i in range(np_bl):
    grid[i]=y3[0][i]
    grid[-i-1]=span-y3[0][i]
for i in range(1,np_free-1):
    grid[i+np_bl-1]=y4[0][i]    
for i in range(1,np_free):
    grid[-i-np_bl]=span-y4[0][i]

# %%
print p4.coeffs
# Out:
# [  1.45712500e-01   4.28750000e-03  -5.02081486e-13   5.04604508e-13
#   -2.54831616e-13   5.24902859e-14  -5.12224354e-16   1.82031662e-18
#   -2.27539577e-21]

# %%
plt.figure()
plt.plot(grid[:])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print grid[-1]
# Out:
# 1.0

# %%
cd ~/drive1/LPT_work/C24_endwall/
# Out:
# /media/drive1/LPT_work/C24_endwall

# %%
ifile=open('span_grid_coarse_span2.dat','w')
ifile.write('%i \n'%n_tot)
for i in range(n_tot):
    ifile.write('%30.20f \n'%grid[i])
ifile.close()

# %%
for i in range(4):
    plt.figure()
    plt.plot(np.diff(grid[:],n=i))
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.axes(aspect='equal')
for i in range(n_tot):
    plt.plot([0.,0.3],[grid[i],grid[i]],'k')
# Out:
# <img src="data:image/png;base64,...">

# %%
print x.size

# %% [markdown]
# # Plot resulting blasius profile

# %%
ifil=open('blasius.dat')
n_blas=int(ifil.readline())
profs=np.empty([5,n_blas])
for i in range(n_blas):
    tmep=ifil.readline().split()
    for j in range(5):
        profs[j,i]=float(tmep[j])

# %%
plt.figure()
plt.plot(profs[1,:],profs[0,:])

# %%
x=np.linspace(0.,2.,num=50)
y=np.tanh(x*4.)

# %%
plt.figure()
plt.plot(x,y)

# %%
0.799/(192.+48.)

# %%
ifile=open('fort.200','r')
temp=ifile.readline().split()
nyp=int(temp[0])
nzp=int(temp[1])
data=np.empty([5,nzp,nyp])
for j in range(nzp):
    for i in range(nyp):
        temp=ifile.readline().split()
        for k in range(5):
            data[k,j,i]=float(temp[k])

# %%
x=np.linspace(1.,float(nyp),num=nyp)
y=np.linspace(1.,float(nzp),num=nzp)
X,Y=np.meshgrid(x,y)

# %%
plt.figure()
plt.contourf(X,Y,data[1,:,:])
plt.colorbar()

# %%
plt.figure()
plt.plot(data[4,:,0])

# %%
ifile=open('fort.300','r')
temp=ifile.readline().split()
nxp=int(temp[0])
nyp=int(temp[1])
nzp=int(temp[2])
data=np.empty([5,nzp,nyp,nxp])
for j in range(nzp):
    for i in range(nyp):
        for m in range(nxp):
            temp=ifile.readline().split()
            for k in range(5):
                data[k,j,i,m]=float(temp[k])
data1=np.empty([5,nzp,nyp,nxp])
for j in range(nzp):
    for i in range(nyp):
        for m in range(nxp):
            temp=ifile.readline().split()
            for k in range(5):
                data1[k,j,i,m]=float(temp[k])

# %%
x=np.linspace(1.,float(nyp),num=nyp)
y=np.linspace(1.,float(nzp),num=nzp)
X,Y=np.meshgrid(x,y)

# %%
plt.figure()
plt.contourf(X,Y,data[4,:,:,2])
plt.colorbar()

# %%
plt.figure()
plt.contourf(X,Y,data1[4,:,:,1])
plt.colorbar()

# %%
np_unif=66
span_unif=0.2
unif_grid=np.linspace(0,span_unif,num=np_unif+1)

# %%
ofile=open('span_grid_old.dat','w')
ofile.write('%i \n'%np_unif)
for j in range(np_unif):
    ofile.write('%25.20f \n'%unif_grid[j])
ofile.close()
