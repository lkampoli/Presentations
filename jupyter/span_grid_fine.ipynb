# %%
# %matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt
import tools

# %%
np_bl=120
bl_thick=0.1
span=1.
spacing_wall=0.0005

# %%
sp_half=span/2.

# %%
con=[]
Vcon=[]
### Value constraints
Vcon.append([1,0.0])
Vcon.append([np_bl,bl_thick])
con.append(Vcon)
### 1.st Derivative/spacing constraint
Dcon=[]
Dcon.append([1,spacing_wall])
con.append(Dcon)
### 2.nd Deriv
Dcon=[]
Dcon.append([1,0.0])
Dcon.append([np_bl,0])
con.append(Dcon)
### 3.rd Deriv
Dcon=[]
Dcon.append([1,0.0])
Dcon.append([np_bl,0])
con.append(Dcon)
### 4.th Deriv
Dcon=[]
Dcon.append([1,0.0])
Dcon.append([np_bl,0])
con.append(Dcon)

p3=tools.polynomial(con)
        
x3=range(1,Vcon[-1][0]+1)
y3=np.zeros(len(x3))
y3=p3.evaluate(x3,maxd=6)

sp_free=y3[1][-1]
print (span/2.-bl_thick)
np_free=int((span/2.-bl_thick)/sp_free)+1
print y3[1][0],y3[1][-1]
print 'Points in free stream ',np_free
con=[]
Vcon=[]
### Value constraints
Vcon.append([1,bl_thick])
Vcon.append([np_free,span/2])
con.append(Vcon)
### 1.st Derivative/spacing constraint
Dcon=[]
Dcon.append([1,sp_free])
con.append(Dcon)
### 2.nd Deriv
Dcon=[]
Dcon.append([1,0.0])
Dcon.append([np_free,0])
con.append(Dcon)
## 3rd Deriv
Dcon=[]
Dcon.append([1,0.0])
Dcon.append([np_free,0])
con.append(Dcon)

## 4th Deriv
Dcon=[]
Dcon.append([1,0.0])
Dcon.append([np_free,0])
con.append(Dcon)

p4=tools.polynomial(con)
x4=range(1,Vcon[-1][0]+1)
y4=np.zeros(len(x4))
y4=p4.evaluate(x4,maxd=6)


print 'maximum spacing and ratio between highest and gen spacing', max(y3[1][:]), max(y3[1][:])/y3[1][0] 
print 'maximum spacing and ratio between highest and gen spacing', max(y3[1]), min(y3[1]) 
print
# Out:
# number of conditions 9
# order of polynomial function is 8
# 0.4
# 0.0005 0.00118067226891
# Points in free stream  339
# number of conditions 9
# order of polynomial function is 8
# maximum spacing and ratio between highest and gen spacing 0.00118067226891 2.36134453782
# maximum spacing and ratio between highest and gen spacing 0.00118067226891 0.0005

# %%
n_tot=2*np_bl+np_free*2-3
grid=np.empty(n_tot)
for i in range(np_bl):
    grid[i]=y3[0][i]
    grid[-i-1]=1.-y3[0][i]
for i in range(1,np_free-1):
    grid[i+np_bl-1]=y4[0][i]    
for i in range(1,np_free):
    grid[-i-np_bl]=1.-y4[0][i]

# %%
print p4.coeffs
# Out:
# [  9.88193277e-02   1.18067227e-03  -2.98654831e-14   2.99535820e-14
#   -1.50650197e-14   3.06607118e-15  -1.77758344e-17   3.72349974e-20
#   -2.73786746e-23]

# %%
plt.figure()
plt.plot(grid[:])
# Out:
# <img src="data:image/png;base64,...">

# %%
print grid[-1]
# Out:
# 1.0

# %%
cd ~/cmg/cases/cascade_endwall/
# Out:
# /home/rp3e11/cmg/cases/cascade_endwall

# %%
ifile=open('span_grid.dat','w')
ifile.write('%i \n'%n_tot)
for i in range(n_tot):
    ifile.write('%30.20f \n'%grid[i])
ifile.close()

# %%
for i in range(4):
    plt.figure()
    plt.plot(np.diff(grid[:],n=i))
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
plt.figure()
plt.axes(aspect='equal')
for i in range(n_tot):
    plt.plot([0.,0.3],[grid[0,i],grid[0,i]],'k')
# Out:
# <div id='c44417d3-3fa6-4114-8128-6a877f6b4e53'></div>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-cca05c916e89> in <module>()
#       2 plt.axes(aspect='equal')
#       3 for i in range(n_tot):
# ----> 4     plt.plot([0.,0.3],[grid[0,i],grid[0,i]],'k')
#
# IndexError: too many indices for array

# %%
print x.size

# %% [markdown]
# # Plot resulting blasius profile

# %%
ifil=open('blasius.dat')
n_blas=int(ifil.readline())
profs=np.empty([5,n_blas])
for i in range(n_blas):
    tmep=ifil.readline().split()
    for j in range(5):
        profs[j,i]=float(tmep[j])

# %%
plt.figure()
plt.plot(profs[1,:],profs[0,:])

# %%
x=np.linspace(0.,2.,num=50)
y=np.tanh(x*4.)

# %%
plt.figure()
plt.plot(x,y)

# %%
0.799/(192.+48.)

# %%
ifile=open('fort.200','r')
temp=ifile.readline().split()
nyp=int(temp[0])
nzp=int(temp[1])
data=np.empty([5,nzp,nyp])
for j in range(nzp):
    for i in range(nyp):
        temp=ifile.readline().split()
        for k in range(5):
            data[k,j,i]=float(temp[k])

# %%
x=np.linspace(1.,float(nyp),num=nyp)
y=np.linspace(1.,float(nzp),num=nzp)
X,Y=np.meshgrid(x,y)

# %%
plt.figure()
plt.contourf(X,Y,data[1,:,:])
plt.colorbar()

# %%
plt.figure()
plt.plot(data[4,:,0])

# %%
ifile=open('fort.300','r')
temp=ifile.readline().split()
nxp=int(temp[0])
nyp=int(temp[1])
nzp=int(temp[2])
data=np.empty([5,nzp,nyp,nxp])
for j in range(nzp):
    for i in range(nyp):
        for m in range(nxp):
            temp=ifile.readline().split()
            for k in range(5):
                data[k,j,i,m]=float(temp[k])
data1=np.empty([5,nzp,nyp,nxp])
for j in range(nzp):
    for i in range(nyp):
        for m in range(nxp):
            temp=ifile.readline().split()
            for k in range(5):
                data1[k,j,i,m]=float(temp[k])

# %%
x=np.linspace(1.,float(nyp),num=nyp)
y=np.linspace(1.,float(nzp),num=nzp)
X,Y=np.meshgrid(x,y)

# %%
plt.figure()
plt.contourf(X,Y,data[4,:,:,2])
plt.colorbar()

# %%
plt.figure()
plt.contourf(X,Y,data1[4,:,:,1])
plt.colorbar()
